# %%
import os
import librosa
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook,tqdm

# %%
train_files = os.listdir('../audioData/train/')
val_files = os.listdir('../audioData/val/')
test_files = os.listdir('../audioData/test1/')
test_files_2 = os.listdir('../audioData/test2/')

# %%
train_files[0]
# Out:
# '22478-4-026-m-42-041-ang-ang-ang.wav'

# %%
for file in train_files:
    utterence_ID = file.split("-")[5]
    utterence_ID
# Out:
# '22478-4-026-m-42-041-ang-ang-ang.wav'

# %%
train_files = [file for file in train_files if 'wav' in file]
val_files = [file for file in val_files if 'wav' in file]
test_files = [file for file in test_files if 'wav' in file]
test_files_2 = [file for file in test_files_2 if 'wav' in file]

# %%
os.makedirs('../audioData/train_process/',exist_ok=True)
for file in tqdm(train_files):
    y,sr=librosa.load('../audioData/train/'+file,sr=44100,mono=False)
    y=librosa.to_mono(y)
    itvs = librosa.effects.split(y,frame_length =16384, hop_length =1024,top_db = 20)
    yt=[]
    for st,ed in itvs:
        yt.append(y[st:ed])
    yt = np.concatenate(yt)
    np.save('../audioData/train_process/'+file[:-4]+'.npy',yt)
# Out:
# 100%|██████████| 44353/44353 [13:00<00:00, 56.80it/s]

# %%
os.makedirs('../audioData/val_process/',exist_ok=True)
for file in tqdm(val_files):
    y,sr=librosa.load('../audioData/val/'+file,sr=44100,mono=False)
    y=librosa.to_mono(y)
    itvs = librosa.effects.split(y,frame_length =16384, hop_length =1024,top_db = 20)
    yt=[]
    for st,ed in itvs:
        yt.append(y[st:ed])
    yt = np.concatenate(yt)
    np.save('../audioData/val_process/'+file[:-4]+'.npy',yt)
# Out:
# 100%|██████████| 5390/5390 [01:21<00:00, 65.88it/s]

# %%
os.makedirs('../audioData/test1_process/',exist_ok=True)
for file in tqdm(test_files):
    y,sr=librosa.load('../audioData/test1/'+file,sr=44100,mono=False)
    y=librosa.to_mono(y)
    itvs = librosa.effects.split(y,frame_length =16384, hop_length =1024,top_db = 20)
    yt=[]
    for st,ed in itvs:
        yt.append(y[st:ed])
    yt = np.concatenate(yt)
    np.save('../audioData/test1_process/'+file[:-4]+'.npy',yt)
# Out:
# 100%|██████████| 2734/2734 [00:28<00:00, 94.28it/s]

# %%
os.makedirs('../audioData/test2_process/',exist_ok=True)
for file in tqdm(test_files_2):
    y,sr=librosa.load('../audioData/test2/'+file,sr=44100,mono=False)
    y=librosa.to_mono(y)
    itvs = librosa.effects.split(y,frame_length =16384, hop_length =1024,top_db = 20)
    yt=[]
    for st,ed in itvs:
        yt.append(y[st:ed])
    yt = np.concatenate(yt)
    np.save('../audioData/test2_process/'+file[:-4]+'.npy',yt)
# Out:
# 100%|██████████| 2847/2847 [00:30<00:00, 94.55it/s]

# %%
val_process_files = os.listdir('../audioData/val_process/')

# %%
l = []
for file in val_process_files:
    x = np.load('../audioData/val_process/' + file)
    l.append(len(x))

# %%
plt.plot(l)

# %%
train_process_files = os.listdir('../audioData/train_process/')

# %%
l = []
for file in train_process_files:
    x = np.load('../audioData/train_process/' + file)
    l.append(len(x))
# Out:
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-9-33461afc00a2> in <module>
#       1 l = []
#       2 for file in train_process_files:
# ----> 3     x = np.load('../audioData/train_process/' + file)
#       4     l.append(len(x))
#
# /opt/conda/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     431             else:
#     432                 return format.read_array(fid, allow_pickle=allow_pickle,
# --> 433                                          pickle_kwargs=pickle_kwargs)
#     434         else:
#     435             # Try a pickle
#
# /opt/conda/lib/python3.7/site-packages/numpy/lib/format.py in read_array(fp, allow_pickle, pickle_kwargs)
#     640     version = read_magic(fp)
#     641     _check_version(version)
# --> 642     shape, fortran_order, dtype = _read_array_header(fp, version)
#     643     if len(shape) == 0:
#     644         count = 1
#
# /opt/conda/lib/python3.7/site-packages/numpy/lib/format.py in _read_array_header(fp, version)
#     504     header = _filter_header(header)
#     505     try:
# --> 506         d = safe_eval(header)
#     507     except SyntaxError as e:
#     508         msg = "Cannot parse header: %r\nException: %r"
#
# /opt/conda/lib/python3.7/site-packages/numpy/lib/utils.py in safe_eval(source)
#    1114     import ast
#    1115
# -> 1116     return ast.literal_eval(source)
#    1117
#    1118
#
# /opt/conda/lib/python3.7/ast.py in literal_eval(node_or_string)
#      44     """
#      45     if isinstance(node_or_string, str):
# ---> 46         node_or_string = parse(node_or_string, mode='eval')
#      47     if isinstance(node_or_string, Expression):
#      48         node_or_string = node_or_string.body
#
# /opt/conda/lib/python3.7/ast.py in parse(source, filename, mode)
#      33     Equivalent to compile(source, filename, mode, PyCF_ONLY_AST).
#      34     """
# ---> 35     return compile(source, filename, mode, PyCF_ONLY_AST)
#      36
#      37
#
# KeyboardInterrupt:

# %%
label2emo={'hap':0,'ang':1,'dis':2,'fea':3,'sad':4,'neu':5,'sur':6}

# %%
z = [0]*7
for file in val_process_files:
    label = file.split('.')[0].split('-')[-1]
    z[label2emo[label]]+=1

# %%
z
# Out:
# [627, 759, 810, 581, 826, 1094, 693]

# %%
z = [0]*7
for file in train_process_files:
    label = file.split('.')[0].split('-')[-1]
    z[label2emo[label]]+=1

# %%
z
# Out:
# [5111, 6387, 6785, 4864, 6659, 9167, 5380]

# %%
44353/np.array([5111, 6387, 6785, 4864, 6659, 9167, 5380])
# Out:
# array([8.67794952, 6.94426178, 6.53691968, 9.11862664, 6.6606097 ,
#        4.83833315, 8.24405204])

# %%
label2emo={'hap':0,'ang':1,'dis':2,'fea':3,'sad':4,'neu':5,'sur':6}

# %% [markdown]
# - Modality (01 = full-AV, 02 = video-only, 03 = audio-only).
# - Vocal channel (01 = speech, 02 = song).
# - Emotion (01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised).
# - Emotional intensity (01 = normal, 02 = strong). NOTE: There is no strong intensity for the 'neutral' emotion.
# - Statement (01 = "Kids are talking by the door", 02 = "Dogs are sitting by the door").
# - Repetition (01 = 1st repetition, 02 = 2nd repetition).
# - Actor (01 to 24. Odd numbered actors are male, even numbered actors are female)

# %%
file
# Out:
# '03-02-01-01-01-01-24.wav'

# %%
train_extra_files = dict()
for i in range(1,25):
    z = str(i).zfill(2)
    train_extra_files[i] = os.listdir('../audioData/train_extra/Actor_%s'%z)

# %%
for i in range(1,25):
    z = str(i).zfill(2)
    for file in tqdm(train_extra_files[i]):
        y,sr=librosa.load('../audioData/train_extra/Actor_%s/'%z+file,sr=44100)
        # y=librosa.to_mono(y)
        itvs = librosa.effects.split(y,frame_length =16384, hop_length =1024,top_db = 20)
        yt=[]
        for st,ed in itvs:
            yt.append(y[st:ed])
        yt = np.concatenate(yt)
        
        label = int(file.split('-')[2])
        
        if label == 1 :
            label = 'neu'
        if label == 2:
            continue
        elif label == 3:
            label = 'hap'
        elif label == 4:
            label = 'sad'
        elif label == 5:
            label = 'ang'
        elif label == 6:
            label = 'fea'
        elif label == 7:
            label = 'dis'
        elif label == 8:
            label = 'fea'
        
#         label = label2emo[label]
        
        np.save('../audioData/train_process/'+file[:-4]+'-%s.npy'%label,yt)
# Out:
# 100%|██████████| 44/44 [00:07<00:00,  5.91it/s]
# 100%|██████████| 44/44 [00:07<00:00,  5.80it/s]
# 100%|██████████| 44/44 [00:06<00:00,  6.32it/s]
# 100%|██████████| 44/44 [00:06<00:00,  6.63it/s]
# 100%|██████████| 44/44 [00:07<00:00,  6.03it/s]
# 100%|██████████| 44/44 [00:07<00:00,  6.14it/s]
# 100%|██████████| 44/44 [00:06<00:00,  6.33it/s]
# 100%|██████████| 44/44 [00:07<00:00,  6.09it/s]
# 100%|██████████| 44/44 [00:06<00:00,  6.33it/s]
# 100%|██████████| 44/44 [00:07<00:00,  5.87it/s]
# 100%|██████████| 44/44 [00:06<00:00,  6.57it/s]
# 100%|██████████| 44/44 [00:06<00:00,  6.42it/s]
# 100%|██████████| 44/44 [00:06<00:00,  6.49it/s]
# 100%|██████████| 44/44 [00:06<00:00,  6.65it/s]
# 100%|██████████| 44/44 [00:06<00:00,  6.78it/s]
# 100%|██████████| 44/44 [00:07<00:00,  6.03it/s]
# 100%|██████████| 44/44 [00:07<00:00,  5.84it/s]
# 0it [00:00, ?it/s]
# 100%|██████████| 44/44 [00:07<00:00,  6.23it/s]
# 100%|██████████| 44/44 [00:07<00:00,  6.00it/s]
# 100%|██████████| 44/44 [00:06<00:00,  6.34it/s]
# 100%|██████████| 44/44 [00:07<00:00,  5.73it/s]
# 100%|██████████| 44/44 [00:07<00:00,  6.08it/s]
# 100%|██████████| 44/44 [00:07<00:00,  6.10it/s]

# %%
for i in range(1,25):
    z = str(i).zfill(2)
    for file in tqdm(train_extra_files[i]):
        label = int(file.split('-')[2])
        
        if label == 1 :
            label = 'neu'
        if label == 2:
            continue
        elif label == 3:
            label = 'hap'
        elif label == 4:
            label = 'sad'
        elif label == 5:
            label = 'ang'
        elif label == 6:
            label = 'fea'
        elif label == 7:
            label = 'dis'
        elif label == 8:
            label = 'fea'
        
        label = label2emo[label]
        file_dir = '../audioData/train_process/'+file[:-4]+'-%d.npy'%label
#         print(file_dir)
        os.remove(file_dir)
# Out:
# 100%|██████████| 44/44 [00:00<00:00, 11857.45it/s]
# 100%|██████████| 44/44 [00:00<00:00, 12216.15it/s]
# 100%|██████████| 44/44 [00:00<00:00, 11603.96it/s]
# 100%|██████████| 44/44 [00:00<00:00, 14895.03it/s]
# 100%|██████████| 44/44 [00:00<00:00, 12985.46it/s]
# 100%|██████████| 44/44 [00:00<00:00, 11926.42it/s]
# 100%|██████████| 44/44 [00:00<00:00, 10673.76it/s]
# 100%|██████████| 44/44 [00:00<00:00, 12018.06it/s]
# 100%|██████████| 44/44 [00:00<00:00, 12003.21it/s]
# 100%|██████████| 44/44 [00:00<00:00, 12440.13it/s]
# 100%|██████████| 44/44 [00:00<00:00, 13737.49it/s]
# 100%|██████████| 44/44 [00:00<00:00, 14271.86it/s]
# 100%|██████████| 44/44 [00:00<00:00, 12504.19it/s]
# 100%|██████████| 44/44 [00:00<00:00, 9373.22it/s]
# 100%|██████████| 44/44 [00:00<00:00, 12753.05it/s]
# 100%|██████████| 44/44 [00:00<00:00, 12095.25it/s]
# 100%|██████████| 44/44 [00:00<00:00, 12604.11it/s]
# 0it [00:00, ?it/s]
# 100%|██████████| 44/44 [00:00<00:00, 9003.29it/s]
# 100%|██████████| 44/44 [00:00<00:00, 10076.96it/s]
# 100%|██████████| 44/44 [00:00<00:00, 12244.52it/s]
# 100%|██████████| 44/44 [00:00<00:00, 9772.27it/s]
# 100%|██████████| 44/44 [00:00<00:00, 10852.65it/s]
# 100%|██████████| 44/44 [00:00<00:00, 12082.58it/s]

# %%
h = np.array([5111, 6387, 6785, 4864, 6659, 9167, 5380])
np.sum(h)
# Out:
# 44353

# %%
l =0
for i in range(1,25):
    z = str(i).zfill(2)
    for file in tqdm(train_extra_files[i]):
        label = int(file.split('-')[2])
        
        if label == 1 :
            label = 'neu'
        if label == 2:
            label = 'calm'
            l +=1
            continue
        elif label == 3:
            label = 'hap'
        elif label == 4:
            label = 'sad'
        elif label == 5:
            label = 'ang'
        elif label == 6:
            label = 'fea'
        elif label == 7:
            label = 'dis'
        elif label == 8:
            label = 'fea'
        
        label = label2emo[label]
        h[label]+=1
# Out:
# 100%|██████████| 44/44 [00:00<00:00, 111375.60it/s]
# 100%|██████████| 44/44 [00:00<00:00, 74056.73it/s]
# 100%|██████████| 44/44 [00:00<00:00, 56111.09it/s]
# 100%|██████████| 44/44 [00:00<00:00, 102641.48it/s]
# 100%|██████████| 44/44 [00:00<00:00, 127892.85it/s]
# 100%|██████████| 44/44 [00:00<00:00, 92090.51it/s]
# 100%|██████████| 44/44 [00:00<00:00, 70681.49it/s]
# 100%|██████████| 44/44 [00:00<00:00, 98478.86it/s]
# 100%|██████████| 44/44 [00:00<00:00, 106491.27it/s]
# 100%|██████████| 44/44 [00:00<00:00, 123197.18it/s]
# 100%|██████████| 44/44 [00:00<00:00, 101512.31it/s]
# 100%|██████████| 44/44 [00:00<00:00, 73819.75it/s]
# 100%|██████████| 44/44 [00:00<00:00, 88048.37it/s]
# 100%|██████████| 44/44 [00:00<00:00, 101960.98it/s]
# 100%|██████████| 44/44 [00:00<00:00, 100026.76it/s]
# 100%|██████████| 44/44 [00:00<00:00, 97645.17it/s]
# 100%|██████████| 44/44 [00:00<00:00, 101456.50it/s]
# 0it [00:00, ?it/s]
# 100%|██████████| 44/44 [00:00<00:00, 137109.49it/s]
# 100%|██████████| 44/44 [00:00<00:00, 116288.20it/s]
# 100%|██████████| 44/44 [00:00<00:00, 139072.63it/s]
# 100%|██████████| 44/44 [00:00<00:00, 177451.32it/s]
# 100%|██████████| 44/44 [00:00<00:00, 119759.49it/s]
# 100%|██████████| 44/44 [00:00<00:00, 107109.33it/s]

# %%
h
# Out:
# array([5295, 6571, 6785, 5048, 6843, 9259, 5380])

# %%
np.sum(h)
# Out:
# 45181

# %%
import os
import librosa
import numpy as np
import librosa.display

# %matplotlib inline

# %%
os.makedirs('./train_process_mel/',exist_ok=True)
sr=44100
file = os.listdir('./train_process/')[0]
yt = np.load('./train_process/'+file)
yS = np.abs(librosa.core.stft(yt,n_fft=2048, hop_length=512))
# yS = librosa.feature.melspectrogram(S=librosa.amplitude_to_db(yS),sr=sr,n_mels=128,
#                                         n_fft=2048, hop_length=512,fmax=8000,fmin=60)
# np.save('./train_process_mel/'+file,yS)

# %%
log_mel = librosa.feature.melspectrogram(S=librosa.amplitude_to_db(yS),sr=sr,n_mels=128,
                                        n_fft=2048, hop_length=512,fmax=8000,fmin=60)

# %%
mel_log = librosa.amplitude_to_db(librosa.feature.melspectrogram(S=yS,sr=sr,n_mels=128,
                                        n_fft=2048, hop_length=512,fmax=8000,fmin=60))

# %%
librosa.display.specshow(log_mel)

# %%
librosa.display.specshow(librosa.util.normalize(log_mel))

# %%
librosa.display.specshow(mel_log)

# %%
np.abs(librosa.util.normalize(mel_log)).std()
# Out:
# 0.25727642

# %%
np.abs(librosa.util.normalize(log_mel)).std()
# Out:
# 0.30324513

# %%
np.random.uniform(0,0.15)
# Out:
# 0.12991747550705393

# %%
librosa.util.normalize((yS-yS.min())/(yS.max()-yS.min()))[:,0].sum()
# Out:
# 28.552305

# %%
librosa.display.specshow((yS-yS.min())/(yS.max()-yS.min()))

# %%
librosa.display.specshow(yS)

# %%
librosa.display.specshow(yS)

# %%
librosa.display.specshow(librosa.util.normalize(yS))

# %%
os.makedirs('./val_process_mel/',exist_ok=True)
sr=44100
for file in os.listdir('./val_process/'):
    yt = np.load('./val_process/'+file)
    yS = np.abs(librosa.core.stft(yt,n_fft=2048, hop_length=512))
    yS = librosa.feature.melspectrogram(S=librosa.amplitude_to_db(yS),sr=sr,n_mels=128,
                                            n_fft=2048, hop_length=512,fmax=8000,fmin=60)
    np.save('./val_process_mel/'+file,yS)

# %%
os.makedirs('./test1_process_mel/',exist_ok=True)
sr=44100
for file in os.listdir('./test1_process/'):
    yt = np.load('./test1_process/'+file)
    yS = np.abs(librosa.core.stft(yt,n_fft=2048, hop_length=512))
    yS = librosa.feature.melspectrogram(S=librosa.amplitude_to_db(yS),sr=sr,n_mels=128,
                                            n_fft=2048, hop_length=512,fmax=8000,fmin=60)
    np.save('./test1_process_mel/'+file,yS)

# %%
os.makedirs('./test2_process_mel/',exist_ok=True)
sr=44100
for file in os.listdir('./test2_process/'):
    yt = np.load('./test2_process/'+file)
    yS = np.abs(librosa.core.stft(yt,n_fft=2048, hop_length=512))
    yS = librosa.feature.melspectrogram(S=librosa.amplitude_to_db(yS),sr=sr,n_mels=128,
                                            n_fft=2048, hop_length=512,fmax=8000,fmin=60)
    np.save('./test2_process_mel/'+file,yS)
